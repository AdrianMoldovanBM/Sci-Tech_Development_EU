# %% [markdown]
# <a href="https://colab.research.google.com/github/AdrianMoldovanBM/Sci-Tech_Development_EU/blob/Data_Projects/Sci_Tech_dev_in_Europe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Science & Technology Development in Europe

# %% [markdown]
# ## Importing data

# %%
import pandas as pd
import numpy as np

# %%
st_data = pd.read_excel("/content/Sci-Tech_Development_in_EU.xlsx")

# %% [markdown]
# ## Visualizing data using different methods

# %%
print(st_data) # not an efficient method
# Out:
#        Time     Country Name  \
# 0       NaN              NaN
# 1    2013.0          Austria
# 2    2013.0          Belgium
# 3    2013.0         Bulgaria
# 4    2013.0          Croatia
# ..      ...              ...
# 266  2022.0         Portugal
# 267  2022.0  Slovak Republic
# 268  2022.0         Slovenia
# 269  2022.0            Spain
# 270  2022.0           Sweden
#
#      High-technology exports (% of manufactured exports)  \
# 0                                                  NaN
# 1                                            15.369008
# 2                                            10.639169
# 3                                             8.284389
# 4                                            12.493490
# ..                                                 ...
# 266                                           6.154774
# 267                                           8.392131
# 268                                           8.474567
# ...

# %%
# More efficient ways for visualization
st_data
# Out:
#        Time     Country Name  \
# 0       NaN              NaN
# 1    2013.0          Austria
# 2    2013.0          Belgium
# 3    2013.0         Bulgaria
# 4    2013.0          Croatia
# ..      ...              ...
# 266  2022.0         Portugal
# 267  2022.0  Slovak Republic
# 268  2022.0         Slovenia
# 269  2022.0            Spain
# 270  2022.0           Sweden
#
#      High-technology exports (% of manufactured exports)  \
# 0                                                  NaN
# 1                                            15.369008
# 2                                            10.639169
# 3                                             8.284389
# 4                                            12.493490
# ..                                                 ...
# 266                                           6.154774
# 267                                           8.392131
# 268                                           8.474567
# ...

# %%
st_data.head()
# Out:
#      Time Country Name  High-technology exports (% of manufactured exports)  \
# 0     NaN          NaN                                                NaN
# 1  2013.0      Austria                                          15.369008
# 2  2013.0      Belgium                                          10.639169
# 3  2013.0     Bulgaria                                           8.284389
# 4  2013.0      Croatia                                          12.493490
#
#    High-technology exports (US$)  \
# 0                            NaN
# 1                   2.079297e+10
# 2                   2.301733e+10
# 3                   1.174075e+09
# 4                   9.997882e+08
#
#    ICT goods exports (% of total goods exports)  \
# 0                                           NaN
# 1                                          4.21
# 2                                          1.69
# 3                                          2.35
# 4                                          2.55
#
# ...

# %% [markdown]
# ## Checking properties of data

# %%
type(st_data)
# Out:
# pandas.core.frame.DataFrame

# %%
st_data.shape
# Out:
# (271, 12)

# %%
st_data.size
# Out:
# 3252

# %%
st_data.columns
# Out:
# Index(['Time', 'Country Name',
#        'High-technology exports (% of manufactured exports)',
#        'High-technology exports (US$)',
#        'ICT goods exports (% of total goods exports)',
#        'ICT goods imports (% total goods imports)',
#        'ICT service exports (% of service exports, BoP)',
#        'ICT service exports (BoP, US$)',
#        'Research and development expenditure (% of GDP)',
#        'Researchers in R&D (per million people)',
#        'Scientific and technical journal articles',
#        'Technicians in R&D (per million people)'],
#       dtype='object')

# %%
st_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271 entries, 0 to 270
# Data columns (total 12 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Time                                                 270 non-null    float64
#  1   Country Name                                         270 non-null    object
#  2   High-technology exports (% of manufactured exports)  270 non-null    float64
#  3   High-technology exports (US$)                        270 non-null    float64
#  4   ICT goods exports (% of total goods exports)         270 non-null    float64
#  5   ICT goods imports (% total goods imports)            270 non-null    float64
#  6   ICT service exports (% of service exports, BoP)      267 non-null    float64
#  7   ICT service exports (BoP, US$)                       267 non-null    float64
# ...

# %% [markdown]
# ## Cleaning data

# %%
# Checking for missing values
st_data.isna()
# Out:
#       Time  Country Name  High-technology exports (% of manufactured exports)  \
# 0     True          True                                               True
# 1    False         False                                              False
# 2    False         False                                              False
# 3    False         False                                              False
# 4    False         False                                              False
# ..     ...           ...                                                ...
# 266  False         False                                              False
# 267  False         False                                              False
# 268  False         False                                              False
# 269  False         False                                              False
# 270  False         False                                              False
#
#      High-technology exports (US$)  \
# ...

# %%
st_data.isna().sum()
# Out:
# Time                                                     1
# Country Name                                             1
# High-technology exports (% of manufactured exports)      1
# High-technology exports (US$)                            1
# ICT goods exports (% of total goods exports)             1
# ICT goods imports (% total goods imports)                1
# ICT service exports (% of service exports, BoP)          4
# ICT service exports (BoP, US$)                           4
# Research and development expenditure (% of GDP)         27
# Researchers in R&D (per million people)                 27
# Scientific and technical journal articles               55
# Technicians in R&D (per million people)                186
# dtype: int64

# %%
# Excluding missing values
st_data_clean = st_data.dropna()

# %%
# Verifying results by comparing the original data set with the clean one
st_data.shape
# Out:
# (271, 12)

# %%
st_data_clean.shape
# Out:
# (82, 12)

# %%
st_data.isna().sum()
# Out:
# Time                                                     1
# Country Name                                             1
# High-technology exports (% of manufactured exports)      1
# High-technology exports (US$)                            1
# ICT goods exports (% of total goods exports)             1
# ICT goods imports (% total goods imports)                1
# ICT service exports (% of service exports, BoP)          4
# ICT service exports (BoP, US$)                           4
# Research and development expenditure (% of GDP)         27
# Researchers in R&D (per million people)                 27
# Scientific and technical journal articles               55
# Technicians in R&D (per million people)                186
# dtype: int64

# %%
st_data_clean.isna().sum()
# Out:
# Time                                                   0
# Country Name                                           0
# High-technology exports (% of manufactured exports)    0
# High-technology exports (US$)                          0
# ICT goods exports (% of total goods exports)           0
# ICT goods imports (% total goods imports)              0
# ICT service exports (% of service exports, BoP)        0
# ICT service exports (BoP, US$)                         0
# Research and development expenditure (% of GDP)        0
# Researchers in R&D (per million people)                0
# Scientific and technical journal articles              0
# Technicians in R&D (per million people)                0
# dtype: int64

# %%
st_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271 entries, 0 to 270
# Data columns (total 12 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Time                                                 270 non-null    float64
#  1   Country Name                                         270 non-null    object
#  2   High-technology exports (% of manufactured exports)  270 non-null    float64
#  3   High-technology exports (US$)                        270 non-null    float64
#  4   ICT goods exports (% of total goods exports)         270 non-null    float64
#  5   ICT goods imports (% total goods imports)            270 non-null    float64
#  6   ICT service exports (% of service exports, BoP)      267 non-null    float64
#  7   ICT service exports (BoP, US$)                       267 non-null    float64
# ...

# %%
st_data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 82 entries, 1 to 159
# Data columns (total 12 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Time                                                 82 non-null     float64
#  1   Country Name                                         82 non-null     object
#  2   High-technology exports (% of manufactured exports)  82 non-null     float64
#  3   High-technology exports (US$)                        82 non-null     float64
#  4   ICT goods exports (% of total goods exports)         82 non-null     float64
#  5   ICT goods imports (% total goods imports)            82 non-null     float64
#  6   ICT service exports (% of service exports, BoP)      82 non-null     float64
#  7   ICT service exports (BoP, US$)                       82 non-null     float64
# ...

# %% [markdown]
# ## Exploratory data analysis

# %%
# Descriptive statistics
st_data_clean.describe()
# Out:
#               Time  High-technology exports (% of manufactured exports)  \
# count    82.000000                                          82.000000
# mean   2015.073171                                          15.136983
# std       1.505385                                           8.182397
# min    2013.000000                                           4.700112
# 25%    2014.000000                                           8.077594
# 50%    2015.000000                                          12.982655
# 75%    2016.000000                                          19.046488
# max    2018.000000                                          38.710601
#
#        High-technology exports (US$)  \
# count                   8.200000e+01
# mean                    2.829992e+10
# std                     5.259276e+10
# min                     5.465354e+07
# 25%                     1.692848e+09
# 50%                     8.604880e+09
# 75%                     2.370305e+10
# ...

# %% [markdown]
# ## Generating Boxplot visualizations

# %%
# Importing necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Creating a loop to generate box plots for all columns
columns = st_data_clean.columns
for i in range(2,len(columns)):
  fig = plt.figure(figsize=(10,5))
  sns.boxplot(x=st_data_clean[columns[i]])

# %% [markdown]
# ## Identifying the biggest outliers based on the boxplot and their values

# %%
HTe_max = st_data_clean["High-technology exports (US$)"].max()
print(HTe_max)
# Out:
# 215614575271.0

# %%
st_data_clean[st_data_clean["High-technology exports (US$)"] > 180000000000]
# Out:
#        Time Country Name  High-technology exports (% of manufactured exports)  \
# 11   2013.0      Germany                                          17.294328
# 38   2014.0      Germany                                          17.206016
# 65   2015.0      Germany                                          17.821232
# 92   2016.0      Germany                                          18.079326
# 119  2017.0      Germany                                          15.847326
#
#      High-technology exports (US$)  \
# 11                    2.092606e+11
# 38                    2.156146e+11
# 65                    1.994299e+11
# 92                    2.050766e+11
# 119                   1.956869e+11
#
#      ICT goods exports (% of total goods exports)  \
# 11                                           4.33
# 38                                           4.52
# 65                                           4.65
# 92                                           4.71
# ...

# %%
ICT_sepct = st_data_clean["ICT service exports (% of service exports, BoP)"].max()
print(ICT_sepct)
# Out:
# 43.501208133928785

# %%
st_data_clean[st_data_clean["ICT service exports (% of service exports, BoP)"] > 40]
# Out:
#        Time Country Name  High-technology exports (% of manufactured exports)  \
# 14   2013.0      Ireland                                          24.983735
# 41   2014.0      Ireland                                          24.918696
# 68   2015.0      Ireland                                          28.338726
# 95   2016.0      Ireland                                          32.841586
# 122  2017.0      Ireland                                          29.334010
#
#      High-technology exports (US$)  \
# 14                    2.502787e+10
# 41                    2.584928e+10
# 68                    3.061218e+10
# 95                    3.799186e+10
# 122                   3.518747e+10
#
#      ICT goods exports (% of total goods exports)  \
# 14                                           5.69
# 41                                           5.56
# 68                                           6.00
# 95                                           8.92
# ...

# %%
ICT_seusd = st_data_clean["ICT service exports (BoP, US$)"].max()
print(ICT_seusd)
# Out:
# 77841667224.44841

# %%
st_data_clean[st_data_clean["ICT service exports (BoP, US$)"] > 50000000000]
# Out:
#        Time Country Name  High-technology exports (% of manufactured exports)  \
# 41   2014.0      Ireland                                          24.918696
# 68   2015.0      Ireland                                          28.338726
# 95   2016.0      Ireland                                          32.841586
# 122  2017.0      Ireland                                          29.334010
#
#      High-technology exports (US$)  \
# 41                    2.584928e+10
# 68                    3.061218e+10
# 95                    3.799186e+10
# 122                   3.518747e+10
#
#      ICT goods exports (% of total goods exports)  \
# 41                                           5.56
# 68                                           6.00
# 95                                           8.92
# 122                                          7.87
#
#      ICT goods imports (% total goods imports)  \
# 41                                        8.21
# ...

# %%
st_journals = st_data_clean["Scientific and technical journal articles"].max()
print(st_journals)
# Out:
# 107880.17

# %%
st_data_clean[st_data_clean["Scientific and technical journal articles"] > 80000]
# Out:
#        Time Country Name  High-technology exports (% of manufactured exports)  \
# 11   2013.0      Germany                                          17.294328
# 38   2014.0      Germany                                          17.206016
# 65   2015.0      Germany                                          17.821232
# 92   2016.0      Germany                                          18.079326
# 119  2017.0      Germany                                          15.847326
#
#      High-technology exports (US$)  \
# 11                    2.092606e+11
# 38                    2.156146e+11
# 65                    1.994299e+11
# 92                    2.050766e+11
# 119                   1.956869e+11
#
#      ICT goods exports (% of total goods exports)  \
# 11                                           4.33
# 38                                           4.52
# 65                                           4.65
# 92                                           4.71
# ...

# %% [markdown]
# ## Correlations & Scatterplots

# %%
# Generating the correlation graph
st_data_clean.corr(numeric_only=True).style.background_gradient(cmap="viridis")
# Out:
# <style type="text/css">
# #T_0f216_row0_col0, #T_0f216_row1_col1, #T_0f216_row2_col2, #T_0f216_row3_col3, #T_0f216_row4_col4, #T_0f216_row5_col5, #T_0f216_row6_col6, #T_0f216_row7_col7, #T_0f216_row8_col8, #T_0f216_row9_col9, #T_0f216_row10_col10 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_0f216_row0_col1 {
#   background-color: #460a5d;
#   color: #f1f1f1;
# }
# #T_0f216_row0_col2 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_0f216_row0_col3, #T_0f216_row0_col4 {
#   background-color: #365c8d;
#   color: #f1f1f1;
# }
# #T_0f216_row0_col5 {
#   background-color: #443b84;
#   color: #f1f1f1;
# }
# #T_0f216_row0_col6 {
#   background-color: #443983;
#   color: #f1f1f1;
# }
# #T_0f216_row0_col7, #T_0f216_row5_col9 {
#   background-color: #46307e;
#   color: #f1f1f1;
# }
# #T_0f216_row0_col8 {
#   background-color: #3c508b;
#   color: #f1f1f1;
# }
# #T_0f216_row0_col9 {
#   background-color: #3e4989;
#   color: #f1f1f1;
# }
# #T_0f216_row0_col10 {
# ...

# %%
# Exploring correlation values using Scatterplots
st_data_clean.plot.scatter(x="Researchers in R&D (per million people)", y="Research and development expenditure (% of GDP)")
# Out:
# <Axes: xlabel='Researchers in R&D (per million people)', ylabel='Research and development expenditure (% of GDP)'>

# %%
st_data_clean.plot.scatter(x="Scientific and technical journal articles", y="High-technology exports (US$)")
# Out:
# <Axes: xlabel='Scientific and technical journal articles', ylabel='High-technology exports (US$)'>

# %%
st_data_clean.plot.scatter(x="Technicians in R&D (per million people)", y="Researchers in R&D (per million people)")
# Out:
# <Axes: xlabel='Technicians in R&D (per million people)', ylabel='Researchers in R&D (per million people)'>
